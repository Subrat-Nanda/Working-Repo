# %% [markdown]
# <a href="https://colab.research.google.com/github/Subrat-Nanda/Working-Repo/blob/main/Image_And_VideoProcessing/Wavelet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wavelet
#
# Submitted By : Subrat Kumar Nanda

# %% [markdown]
# ### Camera Image

# %%
import numpy as np
import matplotlib.pyplot as plt

import cv2
import pywt
import pywt.data

# %%
# Load image
original = pywt.data.camera()

# %%
help(pywt.data)
# Out:
# Help on package pywt.data in pywt:
#
# NAME
#     pywt.data
#
# PACKAGE CONTENTS
#     _readers
#     _wavelab_signals
#     create_dat
#
# FILE
#     /usr/local/lib/python3.9/dist-packages/pywt/data/__init__.py

# %%
# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs2 = pywt.dwt2(original, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Lena Image

# %%
from google.colab.patches import cv2_imshow

# %%
image_lena=cv2.imread('/content/sample_data/lena_color.tiff')
image_lena=cv2.resize(image_lena,(256,256))

# %%
# Display Image
cv2_imshow(image_lena)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F356465DDC0>

# %%
# load using opencv and convert to 
img_bgr: np.array = cv2.imread('/content/sample_data/lena_color.tiff', cv2.IMREAD_COLOR)
img_rgb: np.array = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY);
img_rgb=cv2.resize(img_rgb,(256,256))
plt.imshow(img_rgb); 
plt.axis('off');

# %%
# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs2 = pywt.dwt2(img_rgb, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()
